# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import requests
import json

# %% [markdown]
# #### Config File
#
# Because this process involves unique keys for APIs, I have created a file named `apiconfig.json` to contain sensitive data. A template for that file, `apiconfig-template.json` is provided.
#
# So in adition to imports, I will load that file to be used with the apis.

# %%
with open('apiconfig.json') as json_data_file:
    config = json.load(json_data_file)

# %% [markdown]
# # Queries

# %% [markdown]
# ## Alpha Vantage
#
# I will be getting stock information from an API provided by Alpha Vantage (https://www.alphavantage.co/)
#
# Requests to this API require the following:
#
# * apikey: Unique key for verification
#
# * function: The kind of information you are requesting
#
# * symbol: The symbol of the stock you are requesting info about

# %%
av_key = config['av']['key']
av_base_url = 'https://www.alphavantage.co/query/'

# %% [markdown]
# ### Stock Time Series Data

# %% [markdown]
# #### Intraday
#
# https://www.alphavantage.co/documentation/#intraday

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_INTRADAY',
    'symbol':'.inx',
    'interval': '1min',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
intraday1 = pd.DataFrame.from_dict(res_dict['Time Series (1min)'], orient='index')
print(intraday1.shape)
intraday1.head()
# Out:
# Status Code: 200
# {'1. Information': 'Intraday (1min) prices and volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28 16:00:00', '4. Interval': '1min', '5. Output Size': 'Full size', '6. Time Zone': 'US/Eastern'}
# ---------
# (3720, 5)
#                        1. open    2. high     3. low   4. close 5. volume
# 2017-11-14 09:31:00  2577.7500  2577.7500  2575.7200  2575.8500         0
# 2017-11-14 09:32:00  2575.8000  2576.1400  2575.5100  2575.9300         0
# 2017-11-14 09:33:00  2575.8800  2575.8800  2575.2300  2575.2300         0
# 2017-11-14 09:34:00  2575.2400  2575.6000  2575.1500  2575.4700         0
# 2017-11-14 09:35:00  2575.4900  2576.6300  2575.3400  2576.3300         0

# %%
intraday1.to_csv('../datasets/intraday1min.csv')

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_INTRADAY',
    'symbol':'.inx',
    'interval': '60min',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
intraday60 = pd.DataFrame.from_dict(res_dict['Time Series (60min)'], orient='index')
print(intraday60.shape)
intraday60.head()
# Out:
# Status Code: 200
# {'1. Information': 'Intraday (60min) prices and volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28 16:00:00', '4. Interval': '60min', '5. Output Size': 'Full size', '6. Time Zone': 'US/Eastern'}
# ---------
# (67, 5)
#                        1. open    2. high     3. low   4. close 5. volume
# 2017-11-14 10:00:00  2577.7500  2577.7500  2573.1300  2573.5600         0
# 2017-11-14 11:00:00  2573.6200  2579.6600  2566.5600  2578.1200         0
# 2017-11-14 12:00:00  2578.1200  2578.9400  2576.2900  2578.7000         0
# 2017-11-14 13:00:00  2578.6500  2579.4700  2572.9800  2574.2600         0
# 2017-11-14 14:00:00  2574.1900  2577.5400  2572.4100  2576.3700         0

# %%
intraday60.to_csv('../datasets/intraday60min.csv')

# %% [markdown]
# #### Daily
#
# https://www.alphavantage.co/documentation/#daily

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_DAILY',
    'symbol':'.inx',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
daily = pd.DataFrame.from_dict(res_dict['Time Series (Daily)'], orient='index')
print(daily.shape)
daily.head()
# Out:
# Status Code: 200
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}
# ---------
# (4506, 5)
#               1. open    2. high     3. low   4. close   5. volume
# 2000-01-03  1469.2500  1478.0000  1438.3600  1455.2200   931800000
# 2000-01-04  1455.2200  1455.2200  1397.4301  1399.4200  1009000000
# 2000-01-05  1399.4200  1413.2700  1377.6801  1402.1100  1085500000
# 2000-01-06  1402.1100  1411.9000  1392.1000  1403.4500  1092300000
# 2000-01-07  1403.4500  1441.4700  1400.7300  1441.4700  1225200000

# %%
daily.to_csv('../datasets/daily.csv')

# %% [markdown]
# #### Daily Adjusted
#
# https://www.alphavantage.co/documentation/#dailyadj

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_DAILY_ADJUSTED',
    'symbol':'.inx',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
daily_adj = pd.DataFrame.from_dict(res_dict['Time Series (Daily)'], orient='index')
print(daily_adj.shape)
daily_adj.head()
# Out:
# Status Code: 200
# {'1. Information': 'Daily Time Series with Splits and Dividend Events', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28', '4. Output Size': 'Full size', '5. Time Zone': 'US/Eastern'}
# ---------
# (4506, 8)
#               1. open    2. high     3. low   4. close 5. adjusted close  \
# 2000-01-03  1469.2500  1478.0000  1438.3600  1455.2200         1455.2200
# 2000-01-04  1455.2200  1455.2200  1397.4301  1399.4200         1399.4200
# 2000-01-05  1399.4200  1413.2700  1377.6801  1402.1100         1402.1100
# 2000-01-06  1402.1100  1411.9000  1392.1000  1403.4500         1403.4500
# 2000-01-07  1403.4500  1441.4700  1400.7300  1441.4700         1441.4700
#
#              6. volume 7. dividend amount 8. split coefficient
# 2000-01-03   931800000             0.0000               1.0000
# 2000-01-04  1009000000             0.0000               1.0000
# 2000-01-05  1085500000             0.0000               1.0000
# 2000-01-06  1092300000             0.0000               1.0000
# 2000-01-07  1225200000             0.0000               1.0000

# %%
daily_adj.to_csv('../datasets/daily_adj.csv')

# %% [markdown]
# #### Weekly
#
# https://www.alphavantage.co/documentation/#weekly

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_WEEKLY',
    'symbol':'.inx',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
weekly = pd.DataFrame.from_dict(res_dict['Weekly Time Series'], orient='index')
print(weekly.shape)
weekly.head()
# Out:
# Status Code: 200
# {'1. Information': 'Weekly Prices (open, high, low, close) and Volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28', '4. Time Zone': 'US/Eastern'}
# ---------
# (934, 5)
#               1. open    2. high     3. low   4. close   5. volume
# 2000-01-14  1441.4700  1473.0000  1427.0800  1465.1500  5169700000
# 2000-01-21  1465.1500  1465.7100  1438.5400  1441.3600  4455000000
# 2000-01-28  1441.3600  1454.0900  1356.2000  1360.1600  5532100000
# 2000-02-04  1360.1600  1435.9100  1350.1400  1424.3700  5205000000
# 2000-02-11  1424.3700  1444.5500  1378.8900  1387.1200  5100800000

# %%
weekly.to_csv('../datasets/weekly.csv')

# %% [markdown]
# #### Weekly Adjusted
#
# https://www.alphavantage.co/documentation/#weeklyadj

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_WEEKLY_ADJUSTED',
    'symbol':'.inx',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
weekly_adj = pd.DataFrame.from_dict(res_dict['Weekly Adjusted Time Series'], orient='index')
print(weekly_adj.shape)
weekly_adj.head()
# Out:
# Status Code: 200
# {'1. Information': 'Weekly Adjusted Prices and Volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28', '4. Time Zone': 'US/Eastern'}
# ---------
# (934, 7)
#               1. open    2. high     3. low   4. close 5. adjusted close  \
# 2000-01-14  1441.4700  1473.0000  1427.0800  1465.1500         1465.1500
# 2000-01-21  1465.1500  1465.7100  1438.5400  1441.3600         1441.3600
# 2000-01-28  1441.3600  1454.0900  1356.2000  1360.1600         1360.1600
# 2000-02-04  1360.1600  1435.9100  1350.1400  1424.3700         1424.3700
# 2000-02-11  1424.3700  1444.5500  1378.8900  1387.1200         1387.1200
#
#              6. volume 7. dividend amount
# 2000-01-14  5169700000             0.0000
# 2000-01-21  4455000000             0.0000
# 2000-01-28  5532100000             0.0000
# 2000-02-04  5205000000             0.0000
# 2000-02-11  5100800000             0.0000

# %%
weekly_adj.to_csv('../datasets/weekly_adj.csv')

# %% [markdown]
# #### Monthly
#
# https://www.alphavantage.co/documentation/#monthly

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_MONTHLY',
    'symbol':'.inx',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
monthly = pd.DataFrame.from_dict(res_dict['Monthly Time Series'], orient='index')
print(monthly.shape)
monthly.head()
# Out:
# Status Code: 200
# {'1. Information': 'Monthly Prices (open, high, low, close) and Volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28', '4. Time Zone': 'US/Eastern'}
# ---------
# (214, 5)
#               1. open    2. high     3. low   4. close    5. volume
# 2000-02-29  1394.4600  1444.5500  1325.0699  1366.4200  20912000000
# 2000-03-31  1366.4200  1552.8700  1346.6200  1498.5800  26156200000
# 2000-04-28  1498.5800  1527.1899  1339.4000  1452.4301  20106460000
# 2000-05-31  1452.4301  1481.5100  1361.0900  1420.6000  19898300000
# 2000-06-30  1420.6000  1488.9301  1420.6000  1454.6000  21738300000

# %%
monthly.to_csv('../datasets/monthly.csv')

# %% [markdown]
# #### Monthly Adjusted
#
# https://www.alphavantage.co/documentation/#monthlyadj

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'TIME_SERIES_MONTHLY_ADJUSTED',
    'symbol':'.inx',
    'outputsize': 'full'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
monthly_adj = pd.DataFrame.from_dict(res_dict['Monthly Adjusted Time Series'], orient='index')
print(monthly_adj.shape)
monthly_adj.head()
# Out:
# Status Code: 200
# {'1. Information': 'Monthly Adjusted Prices and Volumes', '2. Symbol': '.inx', '3. Last Refreshed': '2017-11-28', '4. Time Zone': 'US/Eastern'}
# ---------
# (214, 7)
#               1. open    2. high     3. low   4. close 5. adjusted close  \
# 2000-02-29  1394.4600  1444.5500  1325.0699  1366.4200         1366.4200
# 2000-03-31  1366.4200  1552.8700  1346.6200  1498.5800         1498.5800
# 2000-04-28  1498.5800  1527.1899  1339.4000  1452.4301         1452.4301
# 2000-05-31  1452.4301  1481.5100  1361.0900  1420.6000         1420.6000
# 2000-06-30  1420.6000  1488.9301  1420.6000  1454.6000         1454.6000
#
#               6. volume 7. dividend amount
# 2000-02-29  20912000000             0.0000
# 2000-03-31  26156200000             0.0000
# 2000-04-28  20106460000             0.0000
# 2000-05-31  19898300000             0.0000
# 2000-06-30  21738300000             0.0000

# %%
monthly_adj.to_csv('../datasets/monthly_adj.csv')

# %% [markdown]
# ### Currency Exchange
#
# https://www.alphavantage.co/documentation/#currency-exchange

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'CURRENCY_EXCHANGE_RATE',
    'from_currency': 'USD',
    'to_currency': 'EUR'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
curr_ex = pd.DataFrame.from_dict(res_dict, orient='index')
print(curr_ex.shape)
curr_ex
# Out:
# Status Code: 200
# (1, 7)
#                                 1. From_Currency Code 2. From_Currency Name  \
# Realtime Currency Exchange Rate                   USD  United States Dollar
#
#                                 3. To_Currency Code 4. To_Currency Name  \
# Realtime Currency Exchange Rate                 EUR                Euro
#
#                                 5. Exchange Rate    6. Last Refreshed  \
# Realtime Currency Exchange Rate       0.84803900  2017-11-15 02:54:53
#
#                                 7. Time Zone
# Realtime Currency Exchange Rate          UTC

# %% [markdown]
# ### Digital / Crypto Currencies
#
# https://www.alphavantage.co/documentation/#currency-daily
#
# I don't really plan to touch these, but it's here if I decide to.

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'DIGITAL_CURRENCY_DAILY',
    'symbol':'BTC',
    'market': 'EUR'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict['Meta Data'])
print('---------')
btc = pd.DataFrame.from_dict(res_dict['Time Series (Digital Currency Daily)'], orient='index')
print(btc.shape)
btc.head()
# Out:
# Status Code: 200
# {'1. Information': 'Daily Prices and Volumes for Digital Currency', '2. Digital Currency Code': 'BTC', '3. Digital Currency Name': 'Bitcoin', '4. Market Code': 'EUR', '5. Market Name': 'Euro', '6. Last Refreshed': '2017-11-14 (end of day)', '7. Time Zone': 'UTC'}
# (1324, 10)
#            1a. open (EUR) 1b. open (USD) 2a. high (EUR) 2b. high (USD)  \
# 2014-04-01   337.24368327   464.98412099   364.98051975   503.40127051
# 2014-04-02   362.45757366   499.96423790   378.60730685   522.79746042
# 2014-04-03   324.45035209   446.63677448   335.26003184   459.90859971
# 2014-04-04   329.00459091   451.30326183   346.56191782   475.10942403
# 2014-04-05   337.57503741   462.59124713   348.37856951   477.39506256
#
#            3a. low (EUR) 3b. low (USD) 4a. close (EUR) 4b. close (USD)  \
# 2014-04-01  337.24368327  464.98412099    358.78143188    494.89346671
# 2014-04-02  322.54905855  444.01946306    325.17983777    447.64098092
# 2014-04-03  313.00047572  430.82392641    328.92592956    451.19536023
# 2014-04-04  320.31248156  439.20296826    337.12013252    461.96787455
# 2014-04-05  327.87261694  449.29505480    341.08598710    467.40178760
#
#                 5. volume 6. market cap (USD)
# 2014-04-01  3611.19706722    1787157.83556112
# 2014-04-02  4198.64707304    1879486.49432025
# 2014-04-03  3294.35738901    1486398.76886005
# 2014-04-04  2079.03735435     960448.46769978
# 2014-04-05  1227.17828134     573585.32240637

# %% [markdown]
# ### Technical Indicators
#
# https://www.alphavantage.co/documentation/#technical-indicators
#
# Includes many indicators that I frankly don't know enough about to know if it's something I will want to use, will hold off for now because there's a ton of them.
#
# * SMA
# * EMA
# * WMA
# * DEMA
# * TEMA
# * TRIMA
# * KAMA
# * MAMA
# * T3
# * MACD
# * MACDEXT
# * STOCH
# * STOCHIF
# * WILLR
# * ADX
# * ADXR
# * APO
# * PPO
# * MOM
# * BOP
# * CCI
# * CMO
# * ROC
# * ROCR
# * AROON
# * AROONOSC
# * MFI
# * TRIX
# * ULTOSC
# * DX
# * MINUS_DI
# * PLUSE_DI
# * MINUS_DM
# * PLUS_DM
# * BBANDS
# * MIDPOINT
# * MIDPRICE
# * SAR
# * TRANGE
# * ATR
# * NATR
# * AD
# * ADOSC
# * OBV
# * HT_TRENDLINE
# * HT_DCPERIOD
# * HT_DCPHASE
# * HT_PHASOR

# %% [markdown]
# ### Sector Performances
#
# https://www.alphavantage.co/documentation/#sector-information

# %%
av_qparams = {
    'apikey': av_key,
    'function': 'SECTOR'
    }
res = requests.get(av_base_url, av_qparams)
print("Status Code:", res.status_code)
res_dict = res.json()
print(res_dict.pop('Meta Data'))
print('---------')
sectors = pd.DataFrame.from_dict(res_dict)
print(sectors.shape)
sectors
# Out:
# Status Code: 200
# {'Information': 'US Sector Performance (realtime & historical)', 'Last Refreshed': '04:10 PM ET 11/28/2017'}
# ---------
# (11, 10)
#                            Rank A: Real-Time Performance  \
# Consumer Discretionary                             1.09%
# Consumer Staples                                   0.78%
# Energy                                             0.82%
# Financials                                         2.58%
# Health Care                                        0.71%
# Industrials                                        1.49%
# Information Technology                             0.18%
# Materials                                          1.17%
# Real Estate                                       -0.28%
# Telecommunication Services                         2.22%
# Utilities                                          0.43%
#
#                            Rank B: 1 Day Performance  \
# Consumer Discretionary                         0.08%
# Consumer Staples                               0.05%
# Energy                                        -1.03%
# Financials                                    -0.04%
# Health Care                                    0.02%
# Industrials                                    0.18%
# Information Technology                        -0.01%
# Materials                                     -0.61%
# Real Estate                                   -0.27%
# Telecommunication Services                     0.39%
# Utilities                                      0.46%
#
#                            Rank C: 5 Day Performance  \
# Consumer Discretionary                         1.16%
# Consumer Staples                               0.09%
# Energy                                        -0.31%
# Financials                                     0.15%
# Health Care                                    0.65%
# Industrials                                    1.39%
# Information Technology                         1.75%
# Materials                                      0.27%
# Real Estate                                    0.01%
# Telecommunication Services                     2.20%
# Utilities                                      0.51%
#
#                            Rank D: 1 Month Performance  \
# Consumer Discretionary                           4.05%
# Consumer Staples                                 2.30%
# Energy                                          -0.73%
# Financials                                      -2.46%
# Health Care                                     -0.57%
# Industrials                                     -1.62%
# Information Technology                           6.24%
# Materials                                       -1.86%
# Real Estate                                      4.24%
# Telecommunication Services                      -0.86%
# Utilities                                        2.10%
#
#                            Rank E: 3 Month Performance  \
# Consumer Discretionary                           6.89%
# Consumer Staples                                 0.56%
# Energy                                           7.15%
# Financials                                       5.69%
# Health Care                                      3.79%
# Industrials                                      4.98%
# Information Technology                          13.44%
# Materials                                        7.37%
# Real Estate                                      2.35%
# Telecommunication Services                      -6.73%
# Utilities                                        1.82%
#
#                            Rank F: Year-to-Date (YTD) Performance  \
# Consumer Discretionary                                     16.22%
# Consumer Staples                                            6.14%
# Energy                                                    -10.77%
# Financials                                                 12.29%
# Health Care                                                18.57%
# Industrials                                                12.04%
# Information Technology                                     38.97%
# Materials                                                  17.12%
# Real Estate                                                 8.68%
# Telecommunication Services                                -16.00%
# Utilities                                                  14.77%
#
#                            Rank G: 1 Year Performance  \
# Consumer Discretionary                         14.33%
# Consumer Staples                                7.62%
# Energy                                         -7.11%
# Financials                                     16.69%
# Health Care                                    17.91%
# Industrials                                    11.59%
# Information Technology                         39.55%
# Materials                                      17.74%
# Real Estate                                    12.51%
# Telecommunication Services                    -10.69%
# Utilities                                      18.95%
#
#                            Rank H: 3 Year Performance  \
# Consumer Discretionary                         33.99%
# Consumer Staples                               12.80%
# Energy                                        -20.66%
# Financials                                     32.39%
# Health Care                                    18.27%
# Industrials                                    22.46%
# Information Technology                         60.04%
# Materials                                      15.81%
# Real Estate                                       NaN
# Telecommunication Services                     -7.97%
# Utilities                                      23.08%
#
#                            Rank I: 5 Year Performance  \
# Consumer Discretionary                        102.92%
# Consumer Staples                               54.78%
# Energy                                         -6.50%
# Financials                                    104.76%
# Health Care                                   105.34%
# Industrials                                    89.16%
# Information Technology                        142.71%
# Materials                                      59.55%
# Real Estate                                       NaN
# Telecommunication Services                      1.60%
# Utilities                                      62.49%
#
#                            Rank J: 10 Year Performance
# Consumer Discretionary                         191.91%
# Consumer Staples                                92.43%
# Energy                                          -9.42%
# Financials                                      14.88%
# Health Care                                    133.56%
# Industrials                                     76.26%
# Information Technology                         188.03%
# Materials                                       52.23%
# Real Estate                                        NaN
# Telecommunication Services                      -4.67%
# Utilities                                       34.20%

# %%
sectors.to_csv('../datasets/sectorperformance.csv')

# %% [markdown]
# ## Twitter
#
# I will be using Twitter to try to search for tweets mentioning the stocks I am tracking. I will be using the RESTful API as opposed to the streaming API (https://developer.twitter.com/en/docs)
#
# Requests to this API require the following:
#
# * application key: Unique key for verification

# %% [markdown]
# ### Get OAuth
#
# I will be using application authentication (as opposed to user authentication)
#
# For this section I will follow the steps (https://developer.twitter.com/en/docs/basics/authentication/overview/application-only) to get a token that allows the application to make requests to the twitter API.
#
# For the sake of security, my secret keys are in a hidden file, they will be read in and assigned to the two values below, and then used.

# %%
tw_consumer_key = config['twitter']['consumer_key']
tw_consumer_secret = config['twitter']['consumer_secret']

# %% [markdown]
# Encode them according to twitter's expectations

# %%
import base64

# %%
tw_creds = tw_consumer_key + ":" + tw_consumer_secret

tw_creds_encoded = base64.b64encode(tw_creds.encode()).decode()

# %% [markdown]
# Now make POST request to Twitter to get token.

# %%
token_url = 'https://api.twitter.com/oauth2/token/'

headers = {
    'Authorization': 'Basic {}'.format(tw_creds_encoded),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}

qparams = {
    'grant_type': 'client_credentials'
}

res = requests.post(token_url, headers=headers, params=qparams)
print(res.status_code)
response = res.json()
# Out:
# 200

# %%
response['token_type']
# Out:
# 'bearer'

# %% [markdown]
# Correct token type, save that token!

# %%
tw_token = response['access_token']

# %% [markdown]
# ### Search Tweets
#
# This will be an example of searching for tweets (https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html).

# %%
tw_base_url = 'https://api.twitter.com/1.1/search/tweets.json'

tw_headers = {
    'Authorization': 'Bearer {}'.format(tw_token)
}

tw_qparams = {
    'lang': 'en',
    'q': 'S&P500',
    'count': '100'
    }
res = requests.get(tw_base_url, params=tw_qparams, headers=tw_headers)
print("Status Code:", res.status_code)
res_dict = res.json()
# Out:
# Status Code: 200

# %%
res_dict['search_metadata']
# Out:
# {'completed_in': 0.055,
#  'count': 100,
#  'max_id': 930623372127453184,
#  'max_id_str': '930623372127453184',
#  'next_results': '?max_id=930452454344445951&q=S%26P500&lang=en&count=100&include_entities=1',
#  'query': 'S%26P500',
#  'refresh_url': '?since_id=930623372127453184&q=S%26P500&lang=en&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
tweets = pd.DataFrame(res_dict['statuses'])
print(tweets.shape)
tweets.head()
# Out:
# (100, 30)
#   contributors coordinates                      created_at  \
# 0         None        None  Wed Nov 15 02:27:56 +0000 2017
# 1         None        None  Wed Nov 15 02:23:29 +0000 2017
# 2         None        None  Wed Nov 15 02:04:40 +0000 2017
# 3         None        None  Wed Nov 15 02:02:21 +0000 2017
# 4         None        None  Wed Nov 15 01:54:26 +0000 2017
#
#                                             entities extended_entities  \
# 0  {'hashtags': [{'text': 'pressure', 'indices': ...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited   geo                  id              id_str  \
# 0               0      False  None  930623372127453184  930623372127453184
# 1               0      False  None  930622250297860096  930622250297860096
# 2               0      False  None  930617516866465792  930617516866465792
# 3               0      False  None  930616933128404993  930616933128404993
# 4               0      False  None  930614941937053697  930614941937053697
#
#                          ...                         quoted_status  \
# 0                        ...                                   NaN
# 1                        ...                                   NaN
# 2                        ...                                   NaN
# 3                        ...                                   NaN
# 4                        ...                                   NaN
#
#    quoted_status_id quoted_status_id_str  retweet_count retweeted  \
# 0               NaN                  NaN              0     False
# 1               NaN                  NaN             64     False
# 2               NaN                  NaN             64     False
# 3               NaN                  NaN             64     False
# 4               NaN                  NaN             64     False
#
#                                     retweeted_status  \
# 0                                                NaN
# 1  {'created_at': 'Tue Nov 14 09:29:13 +0000 2017...
# 2  {'created_at': 'Tue Nov 14 09:29:13 +0000 2017...
# 3  {'created_at': 'Tue Nov 14 09:29:13 +0000 2017...
# 4  {'created_at': 'Tue Nov 14 09:29:13 +0000 2017...
#
#                                               source  \
# 0  <a href="http://twitter.com" rel="nofollow">Tw...
# 1  <a href="http://twitter.com" rel="nofollow">Tw...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com" rel="nofollow">Tw...
# 4  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                 text truncated  \
# 0  NASDAQ shows topping sign. S&amp;P500 added on...      True
# 1  RT @PunchTheLies: A US-based human rights watc...     False
# 2  RT @PunchTheLies: A US-based human rights watc...     False
# 3  RT @PunchTheLies: A US-based human rights watc...     False
# 4  RT @PunchTheLies: A US-based human rights watc...     False
#
#                                                 user
# 0  {'id': 904893106037735426, 'id_str': '90489310...
# 1  {'id': 2561451512, 'id_str': '2561451512', 'na...
# 2  {'id': 1538501102, 'id_str': '1538501102', 'na...
# 3  {'id': 39967131, 'id_str': '39967131', 'name':...
# 4  {'id': 399954147, 'id_str': '399954147', 'name...
#
# [5 rows x 30 columns]

# %% [markdown]
# So the issie here is that Twitter only allows tweets to be searched with a history of 7 days. Doesn't really give a lot to work off of.

# %% [markdown]
# ## Google Trends/Keywords
#
# While not exactly what I had in mind, as I was hoping to be doing it dynamically, I was able to easily download a csv of searches for the S&P by motnh dating back to 2004 (https://trends.google.com/trends/explore?date=all&q=%2Fm%2F016yss).
#
# I am considering that good enough for the current scope of the project.

# %% [markdown]
# ### Load Data

# %%
trends = pd.read_csv('../datasets/sp500searches.csv', skiprows=1)
print(trends.shape)
trends.head()
# Out:
# (167, 2)
#      Month  S&P 500 Index: (Worldwide)
# 0  2004-01                          73
# 1  2004-02                          68
# 2  2004-03                          60
# 3  2004-04                          61
# 4  2004-05                          56
